# %%
#Pdf chatbot with open ai

# %%
# !pip install langchain
# !pip install pypdf
# !pip install openai
# !pip install chromadb
# !pip install tiktoken
# !pip install langchainhub

# %%
from langchain.document_loaders import PyPDFLoader
# from langchain.document_loaders import WebBaseLoade
loader = PyPDFLoader("Mobily AR_2022_English (1).pdf")
docs = loader.load()
# print(loader.load())
# Split documents

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap = 0)
splits = text_splitter.split_documents(docs)

# %%
from langchain.vectorstores import Chroma
from langchain.embeddings import OpenAIEmbeddings
api_key = "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"
vectorstore = Chroma.from_documents(documents=splits,embedding=OpenAIEmbeddings(openai_api_key=api_key))
retriever = vectorstore.as_retriever()

# # Prompt
# # https://smith.langchain.com/hub/rlm/rag-prompt
# Out:
# /home/amiyabhadra/Desktop/Work/pdf chatbot/venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.embeddings.openai.OpenAIEmbeddings` was deprecated in langchain-community 0.0.9 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
from langchain import hub
rag_prompt = hub.pull("rlm/rag-prompt")

from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-4",openai_api_key=api_key, temperature=0)

from langchain.schema.runnable import RunnablePassthrough
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | rag_prompt
    | llm
)
# Out:
# /home/amiyabhadra/Desktop/Work/pdf chatbot/venv/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.chat_models.openai.ChatOpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
rag_chain.invoke("tell me about moboly")
# Out:
# AIMessage(content='Mobily is a telecommunications provider in Saudi Arabia that is adopting advanced innovative technologies. It has launched Mobily Pay, a digital e-wallet app, in partnership with companies like MoneyGram, Apple, and VISA. The company is also committed to environmental and technological development, and has improved its ranking in video experience in 2022.', response_metadata={'token_usage': {'completion_tokens': 68, 'prompt_tokens': 610, 'total_tokens': 678}, 'model_name': 'gpt-4', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None})

# %%
rag_chain.invoke("tell me about its Financial Highlights")
# Out:
# AIMessage(content='The documents provided do not contain specific information about the financial highlights of the entity in question. They only mention the existence of various financial statements such as the Consolidated Statement of Financial Position, Profit or Loss, Comprehensive Income, Cash Flows, and Changes in Shareholders’ Equity in the 2022 annual report of Mobily. For detailed financial highlights, these specific sections of the document should be referred to.', response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 396, 'total_tokens': 478}, 'model_name': 'gpt-4', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None})

# %%
rag_chain.invoke("tell me about its Stakeholder Engagement")
# Out:
# AIMessage(content='Mobily approaches stakeholder engagement with a holistic view, maintaining collaborative relationships with all stakeholders and considering them as important partners. Internally, stakeholders include employees, executives, and the board of directors, while external stakeholders encompass customers, shareholders, suppliers, contractors, communities, regulators, and government. The company also conducts materiality assessments to identify and prioritize sustainability topics that matter most to the business and its stakeholders.', response_metadata={'token_usage': {'completion_tokens': 81, 'prompt_tokens': 533, 'total_tokens': 614}, 'model_name': 'gpt-4', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None})

# %%
x=rag_chain.invoke("tell me about its Stakeholder Engagement")
x=str(x)
x[9:-199]
# Out:
# "Mobily's approach to Stakeholder Engagement involves maintaining collaborative relationships with all stakeholders, viewing them as important partners. Internally, this includes employees, executives, and the board of directors, while external stakeholders include customers, shareholders, suppliers, contractors, communities, regulators, and government. The company also conducts materiality assessments to identify and prioritize sustainability topics that matter most to the business and its stakeholders."
